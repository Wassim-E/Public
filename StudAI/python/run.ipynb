# %%
import requests


def get_residences_from_studyrama():
    url = "https://logement.studyrama.com/api/annuaire?center=1&distance=30&surfacemin=9&loyermax=2000&typeslogement=&meuble=&type=&tri=prix&lat=48.8588897&lng=2.3200410217200766"
    headers = {
        "accept": "*/*",
        "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
        "cache-control": "no-cache",
        "pragma": "no-cache",
        "priority": "u=1, i",
        "sec-ch-ua": '"Google Chrome";v="147", "Not.A/Brand";v="8", "Chromium";v="147"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin"
    }

    response = requests.get(url, headers=headers, allow_redirects=True)
    data = response.json()
    
    return data

# %%
data
# Out:
# [{'id': '27280',
#   'titre': 'ARPEJ "Paul Cézanne"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '27,24 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2022-09/Image1-2-1000x0-c-default.png?itok=resbawhv',
#    'alt': 'photo 1'},
#   'lat': 49.041693,
#   'lng': 2.071816,
#   'loyer': '329',
#   'surface': '14',
#   'url': '/residence-etudiante/cergy/arpej-paul-cezanne'},
#  {'id': '57100',
#   'titre': 'ARPEJ "SCIPION"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '3,32 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2025-11/residence-etudiante-paris-arppej-cipsion-salle-de-bain-scaled-e1727442724217-1000x1000-c-default.jpg?itok=_qt_s_VU',
#    'alt': 'Photo 1'},
#   'lat': 48.838606,
#   'lng': 2.353409,
#   'loyer': '362',
#   'surface': '15',
#   'url': '/residence-etudiante/paris/arpej-scipion'},
#  {'id': '23503',
#   'titre': 'Arpej univercity Perronet',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '19,50 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/arpej_perronet_738480_ARPEJ_Perronet-8-1000x0-c-default.jpg?itok=fUY8gBT9',
#    'alt': 'Photo 1'},
#   'lat': 48.839232,
#   'lng': 2.584887,
#   'loyer': '372',
#   'surface': '16',
#   'url': '/residence-etudiante/champs-sur-marne/arpej-univercity-perronet'},
#  {'id': '851',
#   'titre': 'ARPEJ "Alexandre Manceau"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '18,32 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_575.jpg?itok=f10JtT-i',
#    'alt': 'Photo 1'},
#   'lat': 48.713061,
#   'lng': 2.203711,
#   'loyer': '378',
#   'surface': '18',
#   'url': '/residence-etudiante/palaiseau/arpej-alexandre-manceau'},
#  {'id': '23501',
#   'titre': 'Arpej univercity Meunier',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '19,50 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/meunier-colocation-scaled-1000x0-c-default.jpg?itok=jjmdNQSF',
#    'alt': 'Photo 1'},
#   'lat': 48.841513,
#   'lng': 2.58524,
#   'loyer': '391',
#   'surface': '18',
#   'url': '/residence-etudiante/champs-sur-marne/arpej-univercity-meunier'},
#  {'id': '57095',
#   'titre': 'ARPEJ "Danielle Casanova"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '4,52 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2025-11/paris-18-e-08052025_113807-scaled-1000x1000-c-default.jpg?itok=YU_A-cVR',
#    'alt': 'Photo 1'},
#   'lat': 48.892956,
#   'lng': 2.353766,
#   'loyer': '404',
#   'surface': '17',
#   'url': '/residence-etudiante/paris/arpej-danielle-casanova'},
#  {'id': '886',
#   'titre': 'Arpej Univercity "Les choux de Créteil"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '12,25 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_609.jpg?itok=9t0XNi1v',
#    'alt': 'Photo 1'},
#   'lat': 48.785288,
#   'lng': 2.444506,
#   'loyer': '408',
#   'surface': '16',
#   'url': '/residence-etudiante/creteil/arpej-univercity-les-choux-de-creteil'},
#  {'id': '25216',
#   'titre': 'ARPEJ "Eole"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '5,59 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2022-07/r%C3%A9sidence-eole%20%281%29.jpg?itok=9bPhiy5R',
#    'alt': 'photo 1'},
#   'lat': 48.896308,
#   'lng': 2.371138,
#   'loyer': '410',
#   'surface': '20',
#   'url': '/residence-etudiante/paris/arpej-eole'},
#  {'id': '57098',
#   'titre': 'ARPEJ "MÉDICIS - LE VÉSINET"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '14,04 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2025-11/residence-etudiante-medicis-le-vesinet-08212025_165611-scaled-1000x1000-c-default.jpg?itok=GFSLHYSP',
#    'alt': 'Photo 1'},
#   'lat': 48.890352,
#   'lng': 2.134144,
#   'loyer': '418',
#   'surface': '16',
#   'url': '/residence-etudiante/le-vesinet/arpej-medicis-le-vesinet'},
#  {'id': '888',
#   'titre': 'Arpej Univercity "Renon"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,75 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_611.jpg?itok=0xNMBsi-',
#    'alt': 'Photo 1'},
#   'lat': 48.846858,
#   'lng': 2.424408,
#   'loyer': '418',
#   'surface': '18',
#   'url': '/residence-etudiante/vincennes/arpej-univercity-renon'},
#  {'id': '25215',
#   'titre': 'ARPEJ "Pierre Vidal Naquet"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '10,47 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2022-07/r%C3%A9sidence-pierre-vidal-naquet%20%281%29.jpg?itok=Y3FZk0It',
#    'alt': 'photo 1'},
#   'lat': 48.947066,
#   'lng': 2.370379,
#   'loyer': '423',
#   'surface': '17',
#   'url': '/residence-etudiante/saint-denis/arpej-pierre-vidal-naquet'},
#  {'id': '788',
#   'titre': 'Arpej Univercity "Pierre Bourdieu"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '15,90 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_513.jpg?itok=Ep5y8ezc',
#    'alt': 'Photo 1'},
#   'lat': 48.768448,
#   'lng': 2.488152,
#   'loyer': '424',
#   'surface': '17',
#   'url': '/residence-etudiante/bonneuil-sur-marne/arpej-univercity-pierre-bourdieu'},
#  {'id': '23463',
#   'titre': 'Arpej univercity Oméga',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '6,65 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/bureau-scaled-1000x0-c-default.jpeg?itok=T6VGlPQq',
#    'alt': 'Photo 1'},
#   'lat': 48.909146,
#   'lng': 2.369256,
#   'loyer': '428',
#   'surface': '18',
#   'url': '/residence-etudiante/aubervilliers/arpej-univercity-omega'},
#  {'id': '23512',
#   'titre': 'Arpej univercity Nicolas Copernic ',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '20,42 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/residence-copernic-salle-de-bain-1-scaled-1000x0-c-default.jpeg?itok=KU8SAFBr',
#    'alt': 'Photo 1'},
#   'lat': 48.840914,
#   'lng': 2.597763,
#   'loyer': '431',
#   'surface': '18',
#   'url': '/residence-etudiante/champs-sur-marne/arpej-univercity-nicolas-copernic'},
#  {'id': '57101',
#   'titre': 'ARPEJ "LA BELLE ÉPINE - THIAIS"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '11,62 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2025-11/thiais-08052025_140652-scaled-1000x1000-c-default.JPG?itok=NNyr9wjv',
#    'alt': 'Photo 1'},
#   'lat': 48.759583,
#   'lng': 2.369589,
#   'loyer': '432',
#   'surface': '18',
#   'url': '/residence-etudiante/thiais/arpej-la-belle-epine-thiais'},
#  {'id': '23468',
#   'titre': 'Arpej Univercity Alpha',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '6,85 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/alpha-studio2-scaled-1000x0-c-default.jpg?itok=gAsa6KV4',
#    'alt': 'Photo 2'},
#   'lat': 48.912422,
#   'lng': 2.366517,
#   'loyer': '434',
#   'surface': '18',
#   'url': '/residence-etudiante/aubervilliers/arpej-univercity-alpha'},
#  {'id': '816',
#   'titre': 'Arpej Univercity "Volti"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,78 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_541.jpg?itok=MqMoWlaZ',
#    'alt': 'Photo 1'},
#   'lat': 48.789337,
#   'lng': 2.330952,
#   'loyer': '435',
#   'surface': '16',
#   'url': '/residence-etudiante/cachan/arpej-univercity-volti'},
#  {'id': '810',
#   'titre': 'Arpej Univercity "La Cybèle"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '21,91 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_535.jpg?itok=ktVPFLPy',
#    'alt': 'Photo 1'},
#   'lat': 48.764113,
#   'lng': 2.057728,
#   'loyer': '435',
#   'surface': '19',
#   'url': '/residence-etudiante/voisins-le-bretonneux/arpej-univercity-la-cybele'},
#  {'id': '23508',
#   'titre': 'Arpej univercity André Dunoyer ',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '22,00 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/andre-dunoyer-de-segonzac-cuisine-scaled-1000x0-c-default.jpg?itok=0VanxX2M',
#    'alt': 'Photo 1'},
#   'lat': 48.77877,
#   'lng': 2.045236,
#   'loyer': '436',
#   'surface': '18',
#   'url': '/residence-etudiante/guyancourt/arpej-univercity-andre-dunoyer'},
#  {'id': '23505',
#   'titre': 'Arpej univercity Ampère',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '19,34 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/ampere-salle-de-bain-scaled-1000x0-c-default.jpg?itok=rMXKU9Wi',
#    'alt': 'Photo 1'},
#   'lat': 48.844814,
#   'lng': 2.58346,
#   'loyer': '436',
#   'surface': '23',
#   'url': '/residence-etudiante/champs-sur-marne/arpej-univercity-ampere'},
#  {'id': '25219',
#   'titre': 'ARPEJ "Henri Krasucki" ',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '22,09 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2022-07/henri-krasucki%20%281%29.jpg?itok=vVm42Hrl',
#    'alt': 'photo 1'},
#   'lat': 48.842413,
#   'lng': 2.620927,
#   'loyer': '437',
#   'surface': '18',
#   'url': '/residence-etudiante/noisiel/arpej-henri-krasucki'},
#  {'id': '973',
#   'titre': 'ARPEJ Univercity Paul Delouvrier',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '27,43 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_690.jpg?itok=FDv7oifO',
#    'alt': 'Photo 1'},
#   'lat': 49.043832,
#   'lng': 2.071439,
#   'loyer': '439',
#   'surface': '16',
#   'url': '/residence-etudiante/cergy-pontoise/arpej-univercity-paul-delouvrier'},
#  {'id': '808',
#   'titre': 'Arpej Univercity "Victor Guerreau"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '11,78 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_533.jpg?itok=N0F0TL4q',
#    'alt': 'Photo 1'},
#   'lat': 48.780531,
#   'lng': 2.211742,
#   'loyer': '443',
#   'surface': '19',
#   'url': '/residence-etudiante/velizy-villacoublay/arpej-univercity-victor-guerreau'},
#  {'id': '817',
#   'titre': 'Arpej Univercity "Pierre-Gilles de Gennes"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '22,20 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_542.jpg?itok=90hzmMSn',
#    'alt': 'Photo 1'},
#   'lat': 48.843443,
#   'lng': 2.622506,
#   'loyer': '457',
#   'surface': '17',
#   'url': '/residence-etudiante/noisiel/arpej-univercity-pierre-gilles-de-gennes'},
#  {'id': '974',
#   'titre': 'ARPEJ Univercity Camille Sèe',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,83 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_691.jpg?itok=IaPTo8DY',
#    'alt': 'Photo 1'},
#   'lat': 48.936692,
#   'lng': 2.34408,
#   'loyer': '467',
#   'surface': '18',
#   'url': '/residence-etudiante/saint-denis/arpej-univercity-camille-see'},
#  {'id': '809',
#   'titre': 'Arpej Univercity "Henri Langlois"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '23,50 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_534.jpg?itok=HRCAW60H',
#    'alt': 'Photo 1'},
#   'lat': 48.801777,
#   'lng': 2.010922,
#   'loyer': '469',
#   'surface': '18',
#   'url': '/residence-etudiante/bois-d-arcy/arpej-univercity-henri-langlois'},
#  {'id': '642',
#   'titre': 'Arpej "La Cerisaie"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '11,90 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_371.jpg?itok=wR-qnDeU',
#    'alt': 'Photo 1'},
#   'lat': 48.752027,
#   'lng': 2.328982,
#   'loyer': '472',
#   'surface': '18',
#   'url': '/residence-etudiante/fresnes/arpej-la-cerisaie'},
#  {'id': '806',
#   'titre': 'Arpej Univercity "Jean-François Deniau"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '10,41 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_531.jpg?itok=gRwUw8dC',
#    'alt': 'Photo 1'},
#   'lat': 48.889199,
#   'lng': 2.45465,
#   'loyer': '474',
#   'surface': '18',
#   'url': '/residence-etudiante/noisy-le-sec/arpej-univercity-jean-francois-deniau'},
#  {'id': '821',
#   'titre': 'Arpej Univercity "Chanzy"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '9,47 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_546.jpg?itok=hKt5p0H4',
#    'alt': 'Photo 1'},
#   'lat': 48.88697,
#   'lng': 2.197754,
#   'loyer': '475',
#   'surface': '18',
#   'url': '/residence-etudiante/nanterre/arpej-univercity-chanzy'},
#  {'id': '822',
#   'titre': 'Arpej Univercity "Nicolas Appert"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '6,86 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_547.jpg?itok=EqvvUmDI',
#    'alt': 'Photo 1'},
#   'lat': 48.811912,
#   'lng': 2.380841,
#   'loyer': '481',
#   'surface': '17',
#   'url': '/residence-etudiante/ivry-sur-seine/arpej-univercity-nicolas-appert'},
#  {'id': '794',
#   'titre': 'Arpej Univercity Saint-Exupéry',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '26,60 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_519.jpg?itok=GCONOs1q',
#    'alt': 'Photo 1'},
#   'lat': 48.631299,
#   'lng': 2.431898,
#   'loyer': '487',
#   'surface': '19',
#   'url': '/residence-etudiante/evry-courcouronnes/arpej-univercity-saint-exupery'},
#  {'id': '795',
#   'titre': 'Arpej Univercity "Poséïdon"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '27,53 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_520.jpg?itok=gtJh6gm2',
#    'alt': 'Photo 1'},
#   'lat': 49.044467,
#   'lng': 2.070528,
#   'loyer': '487',
#   'surface': '18',
#   'url': '/residence-etudiante/cergy-pontoise/arpej-univercity-poseidon'},
#  {'id': '23459',
#   'titre': 'Arpej Univercity Philippe Auguste',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,43 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/philippe-auguste-studio-1000x0-c-default.jpg?itok=DYl-P8tQ',
#    'alt': 'photo 1 '},
#   'lat': 48.845623,
#   'lng': 2.43345,
#   'loyer': '490',
#   'surface': '18',
#   'url': '/residence-etudiante/vincennes/arpej-univercity-philippe-auguste'},
#  {'id': '57097',
#   'titre': 'ARPEJ "MASHA JÎNA AMINI - SAINT-DENIS"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,41 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2025-11/arpej-residence-etudiante-masha-jina-amini-saint-denis-08042025_162442-scaled-1000x1000-c-default_0.jpg?itok=Qybeo0Vi',
#    'alt': 'Photo 1'},
#   'lat': 48.924454,
#   'lng': 2.337915,
#   'loyer': '490',
#   'surface': '19',
#   'url': '/residence-etudiante/saint-denis/arpej-masha-jina-amini-saint-denis'},
#  {'id': '741',
#   'titre': 'Arpej "Michel Serres - Le Luzard"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '21,53 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_468.jpg?itok=T4Ot-EVi',
#    'alt': 'Photo 1'},
#   'lat': 48.845648,
#   'lng': 2.613624,
#   'loyer': '495',
#   'surface': '18',
#   'url': '/residence-etudiante/noisiel/arpej-michel-serres-le-luzard'},
#  {'id': '859',
#   'titre': 'Arpej Univercity "Jean-Paul Goude"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,76 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_583.jpg?itok=ZeE6r9ri',
#    'alt': 'Photo 1'},
#   'lat': 48.844307,
#   'lng': 2.423797,
#   'loyer': '500',
#   'surface': '18',
#   'url': '/residence-etudiante/saint-mande/arpej-univercity-jean-paul-goude'},
#  {'id': '860',
#   'titre': 'Arpej Univercity "Neuilly-Roule"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '3,97 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_584.jpg?itok=jVJnjO9W',
#    'alt': 'Photo 1'},
#   'lat': 48.882039,
#   'lng': 2.278738,
#   'loyer': '508',
#   'surface': '19',
#   'url': '/residence-etudiante/neuilly-sur-seine/arpej-univercity-neuilly-roule'},
#  {'id': '880',
#   'titre': 'Résidence Univercity Adèle André Lambert',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '29,54 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_604.jpg?itok=3nfvs-hN',
#    'alt': 'Photo 1'},
#   'lat': 48.758837,
#   'lng': 1.946312,
#   'loyer': '508',
#   'surface': '19',
#   'url': '/residence-etudiante/maurepas/residence-univercity-adele-andre-lambert'},
#  {'id': '57205',
#   'titre': 'YUGO "Paris Palaiseau"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '17,19 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/yugo-primary_logo-fc-rgb-210625_3.png?itok=QSEJL9-v',
#    'alt': 'Yugo'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-03/youfirst-campus_paris-palaiseau_espace-lounge-6.jpg?itok=ws3OkqD-',
#    'alt': 'photo'},
#   'lat': 48.71929,
#   'lng': 2.219294,
#   'loyer': '511',
#   'surface': '9',
#   'url': '/residence-etudiante/palaiseau/yugo-paris-palaiseau'},
#  {'id': '23510',
#   'titre': 'Arpej Univercity George Sand Saint-Denis',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '10,72 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/Fichier_038-scaled-1000x0-c-default.jpeg?itok=QN8BuGeU',
#    'alt': 'Photo 1'},
#   'lat': 48.948221,
#   'lng': 2.375074,
#   'loyer': '512',
#   'surface': '17',
#   'url': '/residence-etudiante/saint-denis/arpej-univercity-george-sand-saint-denis'},
#  {'id': '23514',
#   'titre': 'Arpej univercity Georges Méliès',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,76 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/georges-melies-comfort-studio2-scaled-1000x0-c-default.jpg?itok=PIUd-19O',
#    'alt': 'Photo 1'},
#   'lat': 48.86628,
#   'lng': 2.439226,
#   'loyer': '515',
#   'surface': '16',
#   'url': '/residence-etudiante/montreuil/arpej-univercity-georges-melies'},
#  {'id': '805',
#   'titre': 'Arpej Univercity "André Devambez"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '14,63 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_530.jpg?itok=6r3STAQB',
#    'alt': 'Photo 1'},
#   'lat': 48.853314,
#   'lng': 2.519766,
#   'loyer': '520',
#   'surface': '17',
#   'url': '/residence-etudiante/neuilly-plaisance/arpej-univercity-andre-devambez'},
#  {'id': '853',
#   'titre': 'Arpej Univercity "Campuséo"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '11,60 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_577.jpg?itok=bys-itTo',
#    'alt': 'Photo 1'},
#   'lat': 48.781415,
#   'lng': 2.21394,
#   'loyer': '524',
#   'surface': '21',
#   'url': '/residence-etudiante/velizy-villacoublay/arpej-univercity-campuseo'},
#  {'id': '893',
#   'titre': 'Arpej "Alfred Sisley"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '16,08 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_616.jpg?itok=h5O3zGW1',
#    'alt': 'Photo 1'},
#   'lat': 48.886566,
#   'lng': 2.104275,
#   'loyer': '532',
#   'surface': '18',
#   'url': '/residence-etudiante/le-port-marly/arpej-alfred-sisley'},
#  {'id': '785',
#   'titre': 'Arpej Univercity "les Bords de Seine"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,42 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_510.jpg?itok=87oMTkfn',
#    'alt': 'Photo 1'},
#   'lat': 48.812574,
#   'lng': 2.411103,
#   'loyer': '535',
#   'surface': '19',
#   'url': '/residence-etudiante/alfortville/arpej-univercity-les-bords-de-seine'},
#  {'id': '807',
#   'titre': 'Arpej Univercity Millénium',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '12,07 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_532.jpg?itok=giVw9G71',
#    'alt': 'Photo 1'},
#   'lat': 48.780042,
#   'lng': 2.206811,
#   'loyer': '540',
#   'surface': '18',
#   'url': '/residence-etudiante/velizy-villacoublay/arpej-univercity-millenium'},
#  {'id': '867',
#   'titre': 'Univercity "Baudin"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,39 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_591.jpg?itok=VUJAABtY',
#    'alt': 'Photo 1'},
#   'lat': 48.932797,
#   'lng': 2.297071,
#   'loyer': '544',
#   'surface': '16',
#   'url': '/residence-etudiante/gennevilliers/univercity-baudin'},
#  {'id': '23518',
#   'titre': 'Arpej Univercity Rosa Parks',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '14,10 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/ROSA_PARKS_EAUBONNE04-1000x0-c-default.jpg?itok=Kjhsijz9',
#    'alt': 'Photo 1'},
#   'lat': 48.982639,
#   'lng': 2.278201,
#   'loyer': '546',
#   'surface': '17',
#   'url': '/residence-etudiante/eaubonne/arpej-univercity-rosa-parks'},
#  {'id': '804',
#   'titre': 'Arpej Univercity "Eugène Chevreul"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '14,12 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_529.jpg?itok=mOGySwwV',
#    'alt': 'Photo 1'},
#   'lat': 48.732805,
#   'lng': 2.29677,
#   'loyer': '549',
#   'surface': '17',
#   'url': '/residence-etudiante/massy/arpej-univercity-eugene-chevreul'},
#  {'id': '852',
#   'titre': 'Résidence Arpej Univercity "Frida Kahlo"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '9,03 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_576.jpg?itok=Dt8v10OH',
#    'alt': 'Photo 1'},
#   'lat': 48.862267,
#   'lng': 2.443432,
#   'loyer': '549',
#   'surface': '18',
#   'url': '/residence-etudiante/montreuil/residence-arpej-univercity-frida-kahlo'},
#  {'id': '23499',
#   'titre': 'Arpej univercity Bernard Barataud',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '28,37 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/arpej_bernard_barataud_e_1214476_Y7A0031_15-1000x0-c-default.jpg?itok=CeExkr8V',
#    'alt': 'Photo 1'},
#   'lat': 48.618814,
#   'lng': 2.450795,
#   'loyer': '553',
#   'surface': '18',
#   'url': '/residence-etudiante/evry-courcouronnes/arpej-univercity-bernard-barataud'},
#  {'id': '887',
#   'titre': 'Arpej Univercity "Larose"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,29 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_610.jpg?itok=FKJ9Mn61',
#    'alt': 'Photo 1'},
#   'lat': 48.932434,
#   'lng': 2.301607,
#   'loyer': '559',
#   'surface': '17',
#   'url': '/residence-etudiante/gennevilliers/arpej-univercity-larose'},
#  {'id': '57210',
#   'titre': 'YUGO "Paris Cité Cinéma"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,07 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/yugo-primary_logo-fc-rgb-210625_3.png?itok=QSEJL9-v',
#    'alt': 'Yugo'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-03/yugo_paris_cite_cinema_common-area_2.jpg?itok=jqmnb74f',
#    'alt': 'photo'},
#   'lat': 48.920421,
#   'lng': 2.344489,
#   'loyer': '561',
#   'surface': '10',
#   'url': '/residence-etudiante/saint-denis/yugo-paris-cite-cinema'},
#  {'id': '20248',
#   'titre': 'Arpej Univercity Conservatoire ',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '6,12 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2020-08/r%C3%A9sidence%20arpej%20conservatoire.JPG?itok=JbCKd_Dx',
#    'alt': 'Photo 1'},
#   'lat': 48.889341,
#   'lng': 2.389744,
#   'loyer': '563',
#   'surface': '26',
#   'url': '/residence-etudiante/paris/arpej-univercity-conservatoire'},
#  {'id': '894',
#   'titre': 'Arpej "Edgar Faure"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '16,82 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_617.jpg?itok=_t_Wj-V6',
#    'alt': 'Photo 1'},
#   'lat': 48.719181,
#   'lng': 2.232178,
#   'loyer': '570',
#   'surface': '20',
#   'url': '/residence-etudiante/palaiseau/arpej-edgar-faure'},
#  {'id': '57208',
#   'titre': 'YUGO "Paris Bagnolet"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,36 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/yugo-primary_logo-fc-rgb-210625_3.png?itok=QSEJL9-v',
#    'alt': 'Yugo'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-03/paris-bagnolet_accueil-1.jpg?itok=C2T1w20-',
#    'alt': 'photo'},
#   'lat': 48.866972,
#   'lng': 2.419937,
#   'loyer': '571',
#   'surface': '9',
#   'url': '/residence-etudiante/bagnolet/yugo-paris-bagnolet'},
#  {'id': '667',
#   'titre': 'STUDEA CERGY UNIVERSITE 1',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '29,47 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/nexity_logo.png?itok=QpNhQmhA',
#    'alt': 'Logo Nexity Studéa'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-04/4_PO0000055_142.jpg?itok=obPTMoLx',
#    'alt': 'Image 1 de la résidence STUDEA CERGY UNIVERSITE 1'},
#   'lat': 49.050668,
#   'lng': 2.041536,
#   'loyer': '581',
#   'surface': '17',
#   'url': '/residence-etudiante/cergy/studea-cergy-universite-1'},
#  {'id': '787',
#   'titre': 'Arpej Univercity "Val Pompadour"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '14,06 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_512.jpg?itok=CLVi9NbI',
#    'alt': 'Photo 1'},
#   'lat': 48.763655,
#   'lng': 2.446308,
#   'loyer': '581',
#   'surface': '19',
#   'url': '/residence-etudiante/valenton/arpej-univercity-val-pompadour'},
#  {'id': '815',
#   'titre': "Univercity Porte d'Italie",
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '5,76 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_540.jpg?itok=IFvQoNQ_',
#    'alt': 'Photo 1'},
#   'lat': 48.815351,
#   'lng': 2.362684,
#   'loyer': '583',
#   'surface': '17',
#   'url': '/residence-etudiante/le-kremlin-bicetre/univercity-porte-d-italie'},
#  {'id': '23465',
#   'titre': 'Arpej univercity SImone Veil',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '14,41 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2021-10/RESIDENCE-SIMONE-VEIL-ETUDIANT-ARPEJ-NEUILLY-PLAISANCE-STUDIO-rotated-1000x0-c-default.jpg?itok=QBasOkex',
#    'alt': 'Photo 2'},
#   'lat': 48.860584,
#   'lng': 2.517022,
#   'loyer': '588',
#   'surface': '19',
#   'url': '/residence-etudiante/neuilly-plaisance/arpej-univercity-simone-veil'},
#  {'id': '823',
#   'titre': 'Arpej Univercity "Le Parc"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,32 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_548.jpg?itok=7juxKLV8',
#    'alt': 'Photo 1'},
#   'lat': 48.822892,
#   'lng': 2.403793,
#   'loyer': '589',
#   'surface': '19',
#   'url': '/residence-etudiante/charenton-le-pont/arpej-univercity-le-parc'},
#  {'id': '672',
#   'titre': 'STUDEA CERGY UNIVERSITE 2',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '29,71 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/nexity_logo.png?itok=QpNhQmhA',
#    'alt': 'Logo Nexity Studéa'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-04/4_PO0000054_137.jpg?itok=AE82p9rT',
#    'alt': 'Image 1 de la résidence STUDEA CERGY UNIVERSITE 2'},
#   'lat': 49.052128,
#   'lng': 2.03895,
#   'loyer': '591',
#   'surface': '18',
#   'url': '/residence-etudiante/cergy/studea-cergy-universite-2'},
#  {'id': '818',
#   'titre': 'Arpej Axi\'home "Berthelot"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,44 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_543.jpg?itok=njZlkHnt',
#    'alt': 'Photo 1'},
#   'lat': 48.807534,
#   'lng': 2.235215,
#   'loyer': '597',
#   'surface': '13',
#   'url': '/residence-etudiante/meudon/arpej-axi-home-berthelot'},
#  {'id': '819',
#   'titre': 'Arpej Univercity "Pierre-Gilles de Gennes" (Villejuif)',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,23 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_544.jpg?itok=-HyOkvTA',
#    'alt': 'Photo 1'},
#   'lat': 48.79856,
#   'lng': 2.356789,
#   'loyer': '602',
#   'surface': '17',
#   'url': '/residence-etudiante/villejuif/arpej-univercity-pierre-gilles-de-gennes-villejuif'},
#  {'id': '4589',
#   'titre': 'STUDEA PALAISEAU CENTRE',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '16,97 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/nexity_logo.png?itok=QpNhQmhA',
#    'alt': 'Logo Nexity Studéa'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-04/4_PO0000284_790.jpg?itok=AiLLvTrb',
#    'alt': 'Image 1 de la résidence STUDEA PALAISEAU CENTRE'},
#   'lat': 48.717396,
#   'lng': 2.233121,
#   'loyer': '631',
#   'surface': '17',
#   'url': '/residence-etudiante/palaiseau/studea-palaiseau-centre'},
#  {'id': '873',
#   'titre': 'Arpej Univercity "Wangari Maathai"',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '8,22 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_597.jpg?itok=jkhV0-a4',
#    'alt': 'Photo 1'},
#   'lat': 48.854596,
#   'lng': 2.432134,
#   'loyer': '653',
#   'surface': '18',
#   'url': '/residence-etudiante/montreuil/arpej-univercity-wangari-maathai'},
#  {'id': '56910',
#   'titre': 'STUDEA CHEVILLY-LARUE RUNGIS',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '10,51 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/nexity_logo.png?itok=QpNhQmhA',
#    'alt': 'Logo Nexity Studéa'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-04/4_PO0000333_1111.jpg?itok=w4HowbPx',
#    'alt': 'Image 1 de la résidence STUDEA CHEVILLY-LARUE RUNGIS'},
#   'lat': 48.766908,
#   'lng': 2.352944,
#   'loyer': '630',
#   'surface': '17',
#   'url': '/residence-etudiante/chevilly-larue/studea-chevilly-larue-rungis'},
#  {'id': '708',
#   'titre': 'STUDEA MASSY',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '15,98 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/nexity_logo.png?itok=QpNhQmhA',
#    'alt': 'Logo Nexity Studéa'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-04/4_PO0000267_739.jpg?itok=4AhM-q18',
#    'alt': 'Image 1 de la résidence STUDEA MASSY'},
#   'lat': 48.720269,
#   'lng': 2.262568,
#   'loyer': '635',
#   'surface': '17',
#   'url': '/residence-etudiante/massy/studea-massy'},
#  {'id': '858',
#   'titre': 'Arpej Univercity Carmen Caron',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,38 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/arpej_full.png?itok=BDk_DnmZ',
#    'alt': 'Logo Arpej'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2017-09/1_582.jpg?itok=cagU1kNO',
#    'alt': 'Photo 1'},
#   'lat': 48.908371,
#   'lng': 2.387242,
#   'loyer': '685',
#   'surface': '19',
#   'url': '/residence-etudiante/aubervilliers/arpej-univercity-carmen-caron'},
#  {'id': '749',
#   'titre': 'STUDEA CACHAN',
#   'type': 'Résidence étudiante',
#   'type_slug': 'residence-etudiante',
#   'distance': '7,10 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/nexity_logo.png?itok=QpNhQmhA',
#    'alt': 'Logo Nexity Studéa'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/residences/images/2026-04/4_PO0000264_718.jpg?itok=G1hwZrP7',
#    'alt': 'Image 1 de la résidence STUDEA CACHAN'},
#   'lat': 48.795218,
#   'lng': 2.327558,
#   'loyer': '703',
#   'surface': '19',
#   'url': '/residence-etudiante/cachan/studea-cachan'},
#  {'id': '57206',
#   'titre': 'YUGO "Paris Cité Descartes"',
#   'type': 'Résidence étudiante',
# ...
#    'alt': ''},
#   'lat': 48.826665,
#   'lng': 2.381706,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-nicole-reine-lepaute'},
#  {'id': '2015',
#   'titre': 'Résidence Bonaparte',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '1,05 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.856119,
#   'lng': 2.333715,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-bonaparte'},
#  {'id': '2073',
#   'titre': 'Résidence Simone Weil',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '6,91 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.826677,
#   'lng': 2.239231,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/boulogne-billancourt/residence-simone-weil'},
#  {'id': '1865',
#   'titre': 'Résidence Reims',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '5,09 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.828634,
#   'lng': 2.37218,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-reims'},
#  {'id': '1804',
#   'titre': 'Résidence Les Linandes Mauves Extension',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '27,30 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 49.044091,
#   'lng': 2.074563,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/cergy/residence-les-linandes-mauves-extension'},
#  {'id': '1728',
#   'titre': 'Résidence de Torcy',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '24,48 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.840489,
#   'lng': 2.653417,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/torcy/residence-de-torcy'},
#  {'id': '1930',
#   'titre': 'Résidence Les Aunettes',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '28,10 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.617561,
#   'lng': 2.43356,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/evry/residence-les-aunettes'},
#  {'id': '1749',
#   'titre': 'Résidence Julie Daubié',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '5,52 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.827149,
#   'lng': 2.377945,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-julie-daubie'},
#  {'id': '1875',
#   'titre': 'Résidence Pajol 2',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '4,29 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.886482,
#   'lng': 2.360961,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-pajol-2'},
#  {'id': '2027',
#   'titre': 'Résidence Lunéville',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '5,82 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.886488,
#   'lng': 2.38765,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-luneville'},
#  {'id': '1868',
#   'titre': 'Résidence Avia',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '4,61 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.829702,
#   'lng': 2.275237,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-avia'},
#  {'id': '1569',
#   'titre': 'Résidence Square Bel Air',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '10,11 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.861413,
#   'lng': 2.458173,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/montreuil/residence-square-bel-air'},
#  {'id': '2236',
#   'titre': 'Résidence Vincent Fayo',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '11,03 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.762799,
#   'lng': 2.282691,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/chatenay-malabry/residence-vincent-fayo'},
#  {'id': '1575',
#   'titre': 'Résidence pour la réussite Lourcine',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '3,09 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.837222,
#   'lng': 2.346373,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-pour-la-reussite-lourcine'},
#  {'id': '1723',
#   'titre': 'Résidence Guynemer',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '10,38 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.948285,
#   'lng': 2.361033,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/pierrefitte-sur-seine/residence-guynemer'},
#  {'id': '1880',
#   'titre': 'Résidence des Haies',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '6,11 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.854527,
#   'lng': 2.403314,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-des-haies'},
#  {'id': '1576',
#   'titre': 'Résidence Domrémy',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '4,97 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.82842,
#   'lng': 2.369673,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris-13e-arrondissement/residence-domremy'},
#  {'id': '1730',
#   'titre': 'Résidence Campus',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '9,50 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.915265,
#   'lng': 2.417636,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/bobigny/residence-campus'},
#  {'id': '1805',
#   'titre': 'Résidence Clichy',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '5,11 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.903952,
#   'lng': 2.306477,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/clichy/residence-clichy'},
#  {'id': '1725',
#   'titre': 'Résidence Montesquieu',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '19,60 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.842393,
#   'lng': 2.586722,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/champs-sur-marne/residence-montesquieu'},
#  {'id': '2018',
#   'titre': 'Résidence Grands-Moulins',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '5,39 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.828254,
#   'lng': 2.377162,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-grands-moulins'},
#  {'id': '1722',
#   'titre': 'La Tour de l’Illustration',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '9,42 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.912621,
#   'lng': 2.419674,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/bobigny/la-tour-de-l-illustration'},
#  {'id': '2026',
#   'titre': 'Résidence Aubervilliers',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '4,70 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.887459,
#   'lng': 2.367348,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/paris/residence-aubervilliers'},
#  {'id': '1911',
#   'titre': 'Résidence de Stains',
#   'type': 'Résidence universitaire Crous',
#   'type_slug': 'residence-universitaire-crous',
#   'distance': '11,72 km',
#   'logo_annonceur': {'image': 'https://logement.studycdn.space/sites/default/files/styles/100x58_transparent/public/annonceurs/logos/logo-crous-logement.png?itok=p_31ugwc',
#    'alt': 'logo crous rouge'},
#   'image': {'image': 'https://logement.studycdn.space/sites/default/files/styles/large/public/default_images/default-picture.jpg?itok=irAGh1K9',
#    'alt': ''},
#   'lat': 48.956068,
#   'lng': 2.382102,
#   'loyer': None,
#   'surface': None,
#   'url': '/residence-universitaire-crous/stains/residence-de-stains'}]
